# %% [markdown]
# # Implementing a Neural Network
# In this exercise we will develop a neural network with fully-connected layers to perform a regression task and a classification task. You need to implement two classes, `DenseLayer` and `Feedforward`, and the `train` function `in implementation.py`

# %%
# A bit of setup

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# %autosave 60
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Autosaving every 60 seconds

# %% [markdown]
# ## 1. Implement the two classes and one function (10 points)
#
# In this step, you should implement the two classes and one function mentioned above. The autograder can check the correcness of your two classes, `DenseLayer` and `Feedforward`. Correct implementation of each of the two classes worths 5 points, so you will 10 points if you make both correct.
#
# The autograder cannot check the training function because this function takes too much time to run.

# %% [markdown]
# ## 2. A toy regression problem
#
# By this step, you should already have implemented all necessary classes and functions in `implementation.py`. In this task, we have a toy regression problem. Please the data below and think about this question: is overfitting a problem for this problem? **Please write your answer below** (This particular question has no points, but you may want to show your thought).

# %% [markdown]
# Answer:
# Sometimes overfitting is a problem here. When I tuning parameters, validation error may increase with decrease of training error. But when continue to tune parameters, this phenomena will disappear.

# %%
def target_func(x):
    y = np.sin(1 / x)
    return y

# initialize training and validation sets. 
x_train = np.power(np.random.random_sample([2000, 1]), 4) + 0.05
y_train = target_func(x_train)

x_val = np.power(np.random.random_sample([2000, 1]), 4) + 0.05
y_val = target_func(x_val)

x_train_std = np.std(x_train, axis = 0)
x_train_mean = np.mean(x_train, axis = 0)
x_train_norm = (x_train - x_train_mean)/x_train_std
    
x_val_std = np.std(x_val, axis = 0)
x_val_mean = np.mean(x_val, axis = 0)
x_val_norm = (x_val - x_val_mean)/x_val_std


# plot the function and data points
# Do you worry about overfitting problem?
sort_ind = np.argsort(x_train[:, 0])
plt.plot(x_train[sort_ind, 0], y_train[sort_ind, 0])
plt.plot(x_train[sort_ind, 0], y_train[sort_ind, 0], '.')

# %% [markdown]
# ### Train the model  (5 points)
#
# Now lets run your `train` function on this data. You will need to save your model to a file and submit it. We will test your saved model. You will earn
#  * 2 points if your validation MSE is smaller than 0.1
#  * 4 points if your validation MSE is smaller than 0.05
#  * 5 points if your validation MSE is smaller than 0.01

# %%
from implementation import train

model, history = train(x_train, y_train, x_val, y_val, depth=4, hidden_sizes=[8, 8, 8], 
                       reg_weight=0.00001, num_train_epochs=200, task_type='regression')
# Out:
# Epoch 1/200
# I am in the network function!
# I am in the network function!
#  1/63 [..............................] - ETA: 0s - loss: 1.5650 - accuracy: 0.0000e+00I am in the network function!
# 63/63 [==============================] - 0s 3ms/step - loss: 0.6809 - accuracy: 0.0000e+00 - val_loss: 0.4680 - val_accuracy: 0.0000e+00
# Epoch 2/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.4163 - accuracy: 0.0000e+00 - val_loss: 0.3629 - val_accuracy: 5.0000e-04
# Epoch 3/200
# 63/63 [==============================] - 0s 2ms/step - loss: 0.3354 - accuracy: 0.0000e+00 - val_loss: 0.3189 - val_accuracy: 5.0000e-04
# Epoch 4/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.3159 - accuracy: 0.0000e+00 - val_loss: 0.2862 - val_accuracy: 5.0000e-04
# Epoch 5/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2972 - accuracy: 0.0000e+00 - val_loss: 0.2850 - val_accuracy: 5.0000e-04
# Epoch 6/200
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2953 - accuracy: 0.0000e+00 - val_loss: 0.2775 - val_accuracy: 5.0000e-04
# Epoch 7/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2969 - accuracy: 0.0000e+00 - val_loss: 0.2909 - val_accuracy: 5.0000e-04
# Epoch 8/200
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2947 - accuracy: 0.0000e+00 - val_loss: 0.2717 - val_accuracy: 5.0000e-04
# Epoch 9/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2838 - accuracy: 0.0000e+00 - val_loss: 0.2648 - val_accuracy: 5.0000e-04
# Epoch 10/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2814 - accuracy: 0.0000e+00 - val_loss: 0.2652 - val_accuracy: 5.0000e-04
# Epoch 11/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2781 - accuracy: 0.0000e+00 - val_loss: 0.2614 - val_accuracy: 5.0000e-04
# Epoch 12/200
# 63/63 [==============================] - 0s 2ms/step - loss: 0.2841 - accuracy: 0.0000e+00 - val_loss: 0.2704 - val_accuracy: 5.0000e-04
# Epoch 13/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2825 - accuracy: 0.0000e+00 - val_loss: 0.2612 - val_accuracy: 5.0000e-04
# Epoch 14/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2769 - accuracy: 0.0000e+00 - val_loss: 0.2651 - val_accuracy: 5.0000e-04
# Epoch 15/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2800 - accuracy: 0.0000e+00 - val_loss: 0.2657 - val_accuracy: 5.0000e-04
# Epoch 16/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2818 - accuracy: 0.0000e+00 - val_loss: 0.2708 - val_accuracy: 5.0000e-04
# Epoch 17/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2758 - accuracy: 0.0000e+00 - val_loss: 0.2590 - val_accuracy: 5.0000e-04
# Epoch 18/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2783 - accuracy: 0.0000e+00 - val_loss: 0.2602 - val_accuracy: 5.0000e-04
# Epoch 19/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2738 - accuracy: 0.0000e+00 - val_loss: 0.2557 - val_accuracy: 5.0000e-04
# Epoch 20/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2720 - accuracy: 0.0000e+00 - val_loss: 0.2625 - val_accuracy: 5.0000e-04
# Epoch 21/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2752 - accuracy: 0.0000e+00 - val_loss: 0.2522 - val_accuracy: 5.0000e-04
# Epoch 22/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2756 - accuracy: 0.0000e+00 - val_loss: 0.2531 - val_accuracy: 5.0000e-04
# Epoch 23/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2749 - accuracy: 0.0000e+00 - val_loss: 0.2644 - val_accuracy: 5.0000e-04
# Epoch 24/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2663 - accuracy: 0.0000e+00 - val_loss: 0.2762 - val_accuracy: 5.0000e-04
# Epoch 25/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2712 - accuracy: 0.0000e+00 - val_loss: 0.2370 - val_accuracy: 5.0000e-04
# Epoch 26/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2597 - accuracy: 0.0000e+00 - val_loss: 0.2271 - val_accuracy: 5.0000e-04
# Epoch 27/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2512 - accuracy: 0.0000e+00 - val_loss: 0.2694 - val_accuracy: 5.0000e-04
# Epoch 28/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2281 - accuracy: 0.0000e+00 - val_loss: 0.2101 - val_accuracy: 5.0000e-04
# Epoch 29/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2219 - accuracy: 0.0000e+00 - val_loss: 0.2038 - val_accuracy: 5.0000e-04
# Epoch 30/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2157 - accuracy: 0.0000e+00 - val_loss: 0.2103 - val_accuracy: 5.0000e-04
# Epoch 31/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2229 - accuracy: 0.0000e+00 - val_loss: 0.1963 - val_accuracy: 5.0000e-04
# Epoch 32/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2135 - accuracy: 0.0000e+00 - val_loss: 0.2089 - val_accuracy: 5.0000e-04
# Epoch 33/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2151 - accuracy: 0.0000e+00 - val_loss: 0.1965 - val_accuracy: 5.0000e-04
# Epoch 34/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2087 - accuracy: 0.0000e+00 - val_loss: 0.2022 - val_accuracy: 5.0000e-04
# Epoch 35/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2061 - accuracy: 0.0000e+00 - val_loss: 0.1940 - val_accuracy: 5.0000e-04
# Epoch 36/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2088 - accuracy: 0.0000e+00 - val_loss: 0.2063 - val_accuracy: 5.0000e-04
# Epoch 37/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.2108 - accuracy: 0.0000e+00 - val_loss: 0.1988 - val_accuracy: 5.0000e-04
# Epoch 38/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.
200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0096 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 5.0000e-04
# Epoch 134/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 5.0000e-04
# Epoch 135/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0067 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_accuracy: 5.0000e-04
# Epoch 136/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0107 - val_accuracy: 5.0000e-04
# Epoch 137/200
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 5.0000e-04
# Epoch 138/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0084 - accuracy: 0.0000e+00 - val_loss: 0.0094 - val_accuracy: 5.0000e-04
# Epoch 139/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 5.0000e-04
# Epoch 140/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0129 - accuracy: 0.0000e+00 - val_loss: 0.0152 - val_accuracy: 5.0000e-04
# Epoch 141/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 5.0000e-04
# Epoch 142/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0058 - val_accuracy: 5.0000e-04
# Epoch 143/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0087 - accuracy: 0.0000e+00 - val_loss: 0.0083 - val_accuracy: 5.0000e-04
# Epoch 144/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 5.0000e-04
# Epoch 145/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 5.0000e-04
# Epoch 146/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 5.0000e-04
# Epoch 147/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0079 - accuracy: 0.0000e+00 - val_loss: 0.0147 - val_accuracy: 5.0000e-04
# Epoch 148/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 5.0000e-04
# Epoch 149/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0303 - accuracy: 0.0000e+00 - val_loss: 0.0109 - val_accuracy: 5.0000e-04
# Epoch 150/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0105 - accuracy: 0.0000e+00 - val_loss: 0.0086 - val_accuracy: 5.0000e-04
# Epoch 151/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0061 - val_accuracy: 5.0000e-04
# Epoch 152/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0100 - val_accuracy: 5.0000e-04
# Epoch 153/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0099 - accuracy: 0.0000e+00 - val_loss: 0.0113 - val_accuracy: 5.0000e-04
# Epoch 154/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0090 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_accuracy: 5.0000e-04
# Epoch 155/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 5.0000e-04
# Epoch 156/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0107 - val_accuracy: 5.0000e-04
# Epoch 157/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0056 - val_accuracy: 5.0000e-04
# Epoch 158/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 5.0000e-04
# Epoch 159/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0073 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 5.0000e-04
# Epoch 160/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0104 - val_accuracy: 5.0000e-04
# Epoch 161/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0092 - val_accuracy: 5.0000e-04
# Epoch 162/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0083 - accuracy: 0.0000e+00 - val_loss: 0.0077 - val_accuracy: 5.0000e-04
# Epoch 163/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 5.0000e-04
# Epoch 164/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0054 - val_accuracy: 5.0000e-04
# Epoch 165/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0246 - val_accuracy: 5.0000e-04
# Epoch 166/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0150 - accuracy: 0.0000e+00 - val_loss: 0.0075 - val_accuracy: 5.0000e-04
# Epoch 167/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0186 - accuracy: 0.0000e+00 - val_loss: 0.0112 - val_accuracy: 5.0000e-04
# Epoch 168/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0054 - val_accuracy: 5.0000e-04
# Epoch 169/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0062 - accuracy: 0.0000e+00 - val_loss: 0.0067 - val_accuracy: 5.0000e-04
# Epoch 170/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0070 - val_accuracy: 5.0000e-04
# Epoch 171/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0065 - val_accuracy: 5.0000e-04
# Epoch 172/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0077 - accuracy: 0.0000e+00 - val_loss: 0.0085 - val_accuracy: 5.0000e-04
# Epoch 173/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0095 - accuracy: 0.0000e+00 - val_loss: 0.0066 - val_accuracy: 5.0000e-04
# Epoch 174/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0117 - val_accuracy: 5.0000e-04
# Epoch 175/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0075 - accuracy: 0.0000e+00 - val_loss: 0.0060 - val_accuracy: 5.0000e-04
# Epoch 176/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 5.0000e-04
# Epoch 177/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0056 - val_accuracy: 5.0000e-04
# Epoch 178/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0108 - accuracy: 0.0000e+00 - val_loss: 0.0089 - val_accuracy: 5.0000e-04
# Epoch 179/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0057 - val_accuracy: 5.0000e-04
# Epoch 180/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0165 - accuracy: 0.0000e+00 - val_loss: 0.0745 - val_accuracy: 5.0000e-04
# Epoch 181/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0229 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 5.0000e-04
# Epoch 182/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0103 - val_accuracy: 5.0000e-04
# Epoch 183/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0100 - accuracy: 0.0000e+00 - val_loss: 0.0078 - val_accuracy: 5.0000e-04
# Epoch 184/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0072 - accuracy: 0.0000e+00 - val_loss: 0.0058 - val_accuracy: 5.0000e-04
# Epoch 185/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0091 - accuracy: 0.0000e+00 - val_loss: 0.0082 - val_accuracy: 5.0000e-04
# Epoch 186/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0102 - accuracy: 0.0000e+00 - val_loss: 0.0064 - val_accuracy: 5.0000e-04
# Epoch 187/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0054 - val_accuracy: 5.0000e-04
# Epoch 188/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0065 - accuracy: 0.0000e+00 - val_loss: 0.0074 - val_accuracy: 5.0000e-04
# Epoch 189/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 5.0000e-04
# Epoch 190/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0070 - accuracy: 0.0000e+00 - val_loss: 0.0146 - val_accuracy: 5.0000e-04
# Epoch 191/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0089 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_accuracy: 5.0000e-04
# Epoch 192/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0079 - val_accuracy: 5.0000e-04
# Epoch 193/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0069 - accuracy: 0.0000e+00 - val_loss: 0.0059 - val_accuracy: 5.0000e-04
# Epoch 194/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0061 - accuracy: 0.0000e+00 - val_loss: 0.0056 - val_accuracy: 5.0000e-04
# Epoch 195/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0092 - accuracy: 0.0000e+00 - val_loss: 0.0076 - val_accuracy: 5.0000e-04
# Epoch 196/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0081 - accuracy: 0.0000e+00 - val_loss: 0.0055 - val_accuracy: 5.0000e-04
# Epoch 197/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0063 - accuracy: 0.0000e+00 - val_loss: 0.0062 - val_accuracy: 5.0000e-04
# Epoch 198/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0076 - accuracy: 0.0000e+00 - val_loss: 0.0072 - val_accuracy: 5.0000e-04
# Epoch 199/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0074 - accuracy: 0.0000e+00 - val_loss: 0.0101 - val_accuracy: 5.0000e-04
# Epoch 200/200
# 63/63 [==============================] - 0s 1ms/step - loss: 0.0064 - accuracy: 0.0000e+00 - val_loss: 0.0080 - val_accuracy: 5.0000e-04

# %% [markdown]
# ### Plot training trace and the fitted model

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(1, 1, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Objective history')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
y_pred = model.predict(x_val)

plt.plot(x_val[:, 0], y_pred[:, 0], '.')
# Out:
# I am in the network function!

# %% [markdown]
# ### Save the model
#
# Please save your model as follows. Make sure the saved model can be loaded correctly with `tf.keras.models.load_model('sin_inv_x.kmod')`. *If your model cannot be loaded, you will get zero points for this problem.*

# %%
model.save('sin_inv_x.kmod')
# Out:
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# INFO:tensorflow:Assets written to: sin_inv_x.kmod/assets

# %% [markdown]
# ## 3. Classifying hand-written digits
#
# This task is a classification problem on the famous MNIST dataset.
#
# ### Load the data

# %%
from sklearn.model_selection import train_test_split

# load the dataset
data_train, data_test = tf.keras.datasets.mnist.load_data()

# separate a validation set
x_train, y_train = data_train 
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, train_size=0.8, stratify=y_train)

x_test, y_test = data_test

# treating images as vectors and create one hot representations of labesl

x_train = x_train.reshape([-1, 28 * 28])
x_val = x_val.reshape([-1, 28 * 28])
x_test = x_test.reshape([-1, 28 * 28])

y_train = tf.one_hot(y_train, depth=10).numpy()
y_val = tf.one_hot(y_val, depth=10).numpy()
y_test = tf.one_hot(y_test, depth=10).numpy()


print('Shape of training input: ', x_train.shape)
print('Shape of training labels: ', y_train.shape)
print('Shape of validation input: ', x_val.shape)
print('Shape of validation labels: ', y_val.shape)
print('Shape of test input: ', x_test.shape)
print('Shape of test labels: ', y_test.shape)
# Out:
# Shape of training input:  (48000, 784)
# Shape of training labels:  (48000, 10)
# Shape of validation input:  (12000, 784)
# Shape of validation labels:  (12000, 10)
# Shape of test input:  (10000, 784)
# Shape of test labels:  (10000, 10)

# %%
float_x = x_train.astype(np.float32)

# %%
x_test.dtype
# Out:
# dtype('uint8')

# %%
x_train_std = np.std(x_train, axis = 0)    
x_train_mean = np.mean(x_train, axis = 0)
   
x_val_std = np.std(x_val, axis = 0)
x_val_mean = np.mean(x_val, axis = 0)

# %%
for i in range(len(x_train_std)):
    if x_train_std[i] == 0:
        x_train_std[i] = 1
    else:
        continue
        
for i in range(len(x_val_std)):
    if x_val_std[i] == 0:
        x_val_std[i] = 1
    else:
        continue

# %%
x_train_norm = (x_train - x_train_mean)/x_train_std
x_val_norm = (x_val - x_val_mean)/x_val_std

# %% [markdown]
# ### Train a model

# %%
from implementation import train


model, history = train(x_train, y_train, x_val, y_val, depth = 3, hidden_sizes=[8, 8], reg_weight=0.01, num_train_epochs=40,  task_type='classification')
# Out:
# Epoch 1/40
# I am in the network function!
# I am in the network function!
# 1497/1500 [============================>.] - ETA: 0s - loss: 4.5186 - accuracy: 0.0923I am in the network function!
# 1500/1500 [==============================] - 2s 1ms/step - loss: 4.5143 - accuracy: 0.0923 - val_loss: 2.3943 - val_accuracy: 0.0903
# Epoch 2/40
# 1500/1500 [==============================] - 1s 743us/step - loss: 1.7631 - accuracy: 0.7356 - val_loss: 1.6293 - val_accuracy: 0.8738
# Epoch 3/40
# 1500/1500 [==============================] - 1s 723us/step - loss: 1.6209 - accuracy: 0.8810 - val_loss: 1.6210 - val_accuracy: 0.8782
# Epoch 4/40
# 1500/1500 [==============================] - 1s 698us/step - loss: 1.6135 - accuracy: 0.8872 - val_loss: 1.6058 - val_accuracy: 0.8938
# Epoch 5/40
# 1500/1500 [==============================] - 1s 733us/step - loss: 1.6094 - accuracy: 0.8895 - val_loss: 1.6151 - val_accuracy: 0.8852
# Epoch 6/40
# 1500/1500 [==============================] - 1s 726us/step - loss: 1.6077 - accuracy: 0.8907 - val_loss: 1.6121 - val_accuracy: 0.8867
# Epoch 7/40
# 1500/1500 [==============================] - 1s 721us/step - loss: 1.6066 - accuracy: 0.8920 - val_loss: 1.6119 - val_accuracy: 0.8870
# Epoch 8/40
# 1500/1500 [==============================] - 1s 732us/step - loss: 1.6053 - accuracy: 0.8934 - val_loss: 1.6083 - val_accuracy: 0.8889
# Epoch 9/40
# 1500/1500 [==============================] - 1s 725us/step - loss: 1.6051 - accuracy: 0.8933 - val_loss: 1.6250 - val_accuracy: 0.8738
# Epoch 10/40
# 1500/1500 [==============================] - 1s 724us/step - loss: 1.6045 - accuracy: 0.8944 - val_loss: 1.6086 - val_accuracy: 0.8913
# Epoch 11/40
# 1500/1500 [==============================] - 1s 721us/step - loss: 1.6030 - accuracy: 0.8960 - val_loss: 1.6025 - val_accuracy: 0.8963
# Epoch 12/40
# 1500/1500 [==============================] - 1s 737us/step - loss: 1.5969 - accuracy: 0.9018 - val_loss: 1.5926 - val_accuracy: 0.9057
# Epoch 33/40
# 1500/1500 [==============================] - 1s 736us/step - loss: 1.5959 - accuracy: 0.9029 - val_loss: 1.6013 - val_accuracy: 0.8972
# Epoch 34/40
# 1500/1500 [==============================] - 1s 740us/step - loss: 1.5979 - accuracy: 0.8999 - val_loss: 1.6043 - val_accuracy: 0.8936
# Epoch 35/40
# 1500/1500 [==============================] - 1s 743us/step - loss: 1.5973 - accuracy: 0.9013 - val_loss: 1.6004 - val_accuracy: 0.8974
# Epoch 36/40
# 1500/1500 [==============================] - 1s 716us/step - loss: 1.5981 - accuracy: 0.9004 - val_loss: 1.5940 - val_accuracy: 0.9035
# Epoch 37/40
# 1500/1500 [==============================] - 1s 721us/step - loss: 1.5969 - accuracy: 0.9003 - val_loss: 1.6468 - val_accuracy: 0.8514
# Epoch 38/40
# 1500/1500 [==============================] - 1s 724us/step - loss: 1.5964 - accuracy: 0.9022 - val_loss: 1.5942 - val_accuracy: 0.9028
# Epoch 39/40
# 1500/1500 [==============================] - 1s 715us/step - loss: 1.5968 - accuracy: 0.9015 - val_loss: 1.5964 - val_accuracy: 0.9022
# Epoch 40/40
# 1500/1500 [==============================] - 1s 713us/step - loss: 1.5978 - accuracy: 0.9001 - val_loss: 1.5905 - val_accuracy: 0.9076

# %% [markdown]
# ### Debug the training (10 points)
#
# A neural network with your initial setting may not work straightforwardly, so you will need to diagnose the problems in the training procedure. One strategy for getting insight into what's wrong is to plot the loss function and the accuracies on the training and validation sets during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks. This task gives you a chance to gain some experience. Below, you should experiment with different values of the various hyperparameters, including
#  * data preparation (data normalization and data augmentation)
#  * the achitecture (depth, hidden layer sizes, and activation functions),
#  * optimization (optimization algorithm, learning rate, learning rate decay, batch size, and numer of training epochs)
#  * regularization (regularization weight, dropout).
#
# **Expected results**. You goal in this exercise is to get as good of a result as you can, with a fully-connected Neural Network. Feel free implement your own techniques (e.g. PCA to reduce dimensionality, or adding dropout, or adding features to the solver, etc.).  You should be aim to achieve a classification accuracy of greater than 80% on the test results.
#
# **Grading**. You will get
#   * 5 points if your model has an accuracy over 0.70
#   * 8 points if your model has an accuracy over 0.80
#   * 10 points if your model has an accuracy over 0.90

# %%
# Plot the loss function and train / validation accuracies
plt.subplot(2, 1, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Objective history')
plt.xlabel('Epochs')
plt.ylabel('Loss')

plt.subplot(2, 1, 2)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title('Classification accuracy history')
plt.xlabel('Epoch')
plt.ylabel('Clasification accuracy')
plt.legend()
plt.show()

# %%
from vis_utils import visualize_grid

W1 = model.layers[0].w.numpy()
W1 = W1.transpose()
W1 = W1.reshape([W1.shape[0], 28, 28, 1])

plt.imshow(np.squeeze(visualize_grid(W1)))

# %% [markdown]
# Finally, test the model on the test set and show the accuracy.

# %%
y_pred = model.predict(x_test.astype(np.float32))

acc = np.mean(np.argmax(y_test, axis=1) == np.argmax(y_pred, axis=1))

print('The test accuracy is ', acc)
# Out:
# I am in the network function!
# The test accuracy is  0.9104

# %% [markdown]
# ### Save the model

# %%
model.save('mnist_cls.kmod')
# Out:
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# I am in the network function!
# INFO:tensorflow:Assets written to: mnist_cls.kmod/assets

# %% [markdown]
# ## Question (5 points): what have you learned from this assignment?
#
# Please summarize your model tuning experience into three points below. If possible, please elaborate after your summarization.
#
# *Answer*:

# %% [markdown]
# First, change type of layers to best fit regression or classification.
# Secondly, tune learning rate a little.
# Thirdly, consider changing training epoches.
# Finally, adding hidden layers and network depth.
